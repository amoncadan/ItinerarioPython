# %% [markdown]
# Epa Juan qué mas
#
# Acá otro [enlace a una página](https://www.europeansocialsurvey.org/download.html?file=ESS9e03_1&c=&y=2018&loggedin)
#
# Mira tú aquí te muestro mi taller. Esta data la saqué de la siguiente [página web](https://www.europeansocialsurvey.org/download.html?file=ESS9e03_1&c=&y=2018&loggedin)

# %%
import pandas as pd
import pyreadstat

# %%
datosjuan = pd.read_spss("/home/jc/Downloads/ESS9e03_1.spss/ESS9e03_1.sav")

# %%
datosjuan.head()
# Out:
#         name  essround edition    proddate   idno    cntry nwspol   netusoft  \
# 0  ESS9e03_1       9.0     3.1  17.02.2021   27.0  Austria   60.0  Every day
# 1  ESS9e03_1       9.0     3.1  17.02.2021  137.0  Austria   10.0  Every day
# 2  ESS9e03_1       9.0     3.1  17.02.2021  194.0  Austria   60.0  Most days
# 3  ESS9e03_1       9.0     3.1  17.02.2021  208.0  Austria   45.0  Every day
# 4  ESS9e03_1       9.0     3.1  17.02.2021  220.0  Austria   30.0      Never
#
#   netustm ppltrst  ... inwemm  inwtm   dweight   pspwght   pweight  anweight  \
# 0   180.0       2  ...    7.0   46.0  0.581174  0.218111  0.302091  0.065890
# 1    20.0       7  ...    6.0   73.0  1.062772  0.413473  0.302091  0.124907
# 2   180.0       5  ...   48.0   92.0  1.376509  2.270293  0.302091  0.685836
# 3   120.0       3  ...   49.0  134.0  0.993399  0.386483  0.302091  0.116753
# 4     NaN       5  ...   39.0   40.0  0.377353  1.032102  0.302091  0.311789
#
#   domain      prob stratum     psu
# ...
